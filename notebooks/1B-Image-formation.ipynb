# %% [markdown]
# ## What is image formation?
# Image formation occurs when a **sensor registeres radiation** that has **interacted with physical objects**
#
# ## Projection mathematics
# ![projection-mathematics.png](attachment:8c5ffd51-0c4c-4f61-9280-dd066ad0dcec.png)
#
# ## Perspective projection
# Apparent size of object depends on its distance: far objects appear smaller
# By similar triangles:
# $$(x',y',z') = (-f\frac{x}{z},-f\frac{y}{z},-f)$$
# Ignore third coordinate and mirror
# $$(x',y')=(f\frac{x}{z},f\frac{y}{z})$$
#
# ## Affine projection
# Suitable when scene depth is small relative to average distance from camera
#
# Let magnification $m = f / z_0$ be a position constant and all points in the scene have approximately constant distance $z_0$ to the camera
#
# Leads to weak perspective projection: $(x',y')=(mx,my)$
#
# Orthographic project when $m = 1$: $(x',y')=(x,y)$
#
# ## Radication distortions
# Modern cameras use lenses instead of pinholes
# ![radication-distoritions.png](attachment:3dd71110-fa72-4365-ae37-07659062784b.png)
#
# ## Comapring to human vision
# Cameras imitate the frequency response of the human eye so it is good to know something about it
#
# Computer vision probably would not get as much attention if biological vision (espically human vision) had not proven that it is possible to make important juidgements from 2D images.
#
# ### Colour spaces: RGB
# Default colour space in vision
# Drawback: strongly correlated channels
# ![colour-spaces-rgb.png](attachment:198a915e-6405-4171-805f-2694c629aebd.png)
#
# ### Colour spaces: HSV
# Intuitive colour space, often used in colour selection and manipulation
# Drawback: confounded channels
# ![colour-space-hsv.png](attachment:0579d5cb-58c0-4393-a086-9a73b234ee4d.png)
#
# ### Colour spaces: YCbCr
# Fast to compute, good for compression (reduce the resolution for Cb/Cr), used by TV, jpeg, etc..
# ![colour-spaces-ycbcr.png](attachment:7ba0fd0e-d62d-4f8a-9f4c-6ea47330ebce.png)
#
# ### Colour spaces: L*a*b*
# "Perceptually uniform" colour space
# a.k.a CIELAB
# ![colour-spaces-lab.png](attachment:2ab0ff74-16c7-4683-9234-194e51156558.png)
#
# ## Digital image formation
# ![dif-1.png](attachment:d2d26f36-9895-449d-ba2b-1756004f10d5.png)
# ![dif-2.png](attachment:82abecdb-de7c-4536-b248-b0aa606d562d.png)
# Displaying the digital image
# ![dif-3.png](attachment:f33e0f19-f49c-45c8-b130-3cc7288f434d.png)
# A lot more blur, since we are using less elements.
#
# Comparing the original and digital image
# ![dif-4.png](attachment:5dbbb682-1f28-4637-a3bb-693a22c9a475.png)
#
# ### Digitisation by spatial sampling
# Digitisation converts an analog image to a digital image by sampling the image space
# Sampling discretises the coordinates $x$ and $y$
#
# - Spatial discretisation of a picture function $f(x,y)$
# - Typically a rectangular grid of sampling points is used
# - The $\Delta x \text{ and } \Delta y$ are called the *sampling intervals*
#
# ## Digital colour images
# Each channel is a digital image with the same number of rows and columns
# ![dci.png](attachment:43e7e4d8-59c9-42e0-930a-2d31f3bd4604.png)
#
# ## Spatial resolution
# Spatial resolution - number of pixels per unit of length
# Example: resolution decreases by one half each time.
# ![sr.png](attachment:6655a55e-24b1-4806-95a4-7666307fc32f.png)
# Human faces can be recognised at $64 \times 64$ pixels per face
# Appropriate resolution is essential, too little yields poor recognistion, too much resolution is slow and wastes memory.
#
# ## Quantisation
# Quantisation digitises the image intensity or amplitude values $f(x,y)$, called intensity or gray-level quantisation.
# Gray-level resolution to be chosen per application, e.g. 16, 32, 64, ... 128, 256 levels. Should nbe high enough for huamn perception of shading details, the latter requires about 100 levels for a realistic image, and should not be higher than necessary to avoid wasting storage.
